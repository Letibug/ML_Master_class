# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_iris
dat=load_iris()

# %%
print(dat.target_names)
dat.feature_names
# Out:
# ['setosa' 'versicolor' 'virginica']
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris=pd.DataFrame(dat.data, columns=dat.feature_names)
iris['Species']=dat.target
iris.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'Species'],
#       dtype='object')

# %%
species_map={0:'setosa',1:'versicolor',2:'virginica'}
iris.Species=iris.Species.map(species_map)
iris.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#   Species
# 0  setosa
# 1  setosa
# 2  setosa

# %%
iris.Species.value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: Species, dtype: int64

# %%
iris.columns=['sepal_length','sepal_width','petal_length','petal_width','species']

# %%
iris.plot(kind='scatter', x='sepal_length', y='sepal_width')

# %%
sns.jointplot('sepal_length','sepal_width',data=iris, size=5)

# %%
facet=sns.FacetGrid(iris, hue='species', size=5)
facet.map(plt.scatter, 'sepal_length','sepal_width').add_legend()

# %%
sns.boxplot(iris.species,iris.petal_length)

# %%
sns.distplot(iris.sepal_length, kde=True)

# %%
sns.kdeplot(iris.sepal_length, shade=True)

# %%
sns.countplot(iris.species)

# %%
sns.stripplot(iris.species,iris.petal_length,jitter=True, edgecolor='gray')

# %%
sns.stripplot(iris.species, iris.petal_length)

# %%
sns.violinplot(iris.petal_length)

# %%
sns.violinplot(iris.species,iris.petal_length)

# %%
sns.FacetGrid(iris, hue='species',size=6)\
.map(sns.kdeplot, 'petal_length')\
.add_legend()

# %%
sns.pairplot(iris,hue='species',size=3)

# %%
sns.pairplot(iris, hue='species',size=3, diag_kind='kde')

# %%
iris.boxplot(by='species',figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F67DDD8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001090C780>]], dtype=object)

# %%
from pandas.tools.plotting import andrews_curves
andrews_curves(iris,'species')
